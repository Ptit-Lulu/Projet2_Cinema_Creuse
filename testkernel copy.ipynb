# %%
import duckdb
import pandas as pd

# Configuration immédiate
duckdb.execute("SET force_download=true")
duckdb.execute("SET threads TO 4")  # Utilise plusieurs threads pour accélérer

# %%
# Supprimer les anciennes vues
duckdb.execute("DROP VIEW IF EXISTS titles")
duckdb.execute("DROP VIEW IF EXISTS ratings")
duckdb.execute("DROP VIEW IF EXISTS actors")
duckdb.execute("DROP VIEW IF EXISTS name")
duckdb.execute("DROP VIEW IF EXISTS crew")
duckdb.execute("DROP VIEW IF EXISTS akas")

# %%
url_titles = 'https://datasets.imdbws.com/title.basics.tsv.gz'
url_ratings = 'https://datasets.imdbws.com/title.ratings.tsv.gz'
url_actors = 'https://datasets.imdbws.com/title.principals.tsv.gz'
url_akas = "https://datasets.imdbws.com/title.akas.tsv.gz"
url_tmdb = 'D:/Utilisateurs/Dylan Malis/Téléchargements/tmdb_full.csv'
url_crew = "https://datasets.imdbws.com/title.crew.tsv.gz"
url_name = "https://datasets.imdbws.com/name.basics.tsv.gz"

# %%
duckdb.query(f"CREATE OR REPLACE VIEW titles AS SELECT * FROM read_csv_auto('{url_titles}')")
duckdb.query(f"CREATE OR REPLACE VIEW tmdb AS SELECT * FROM read_csv_auto('{url_tmdb}')")
duckdb.query(f"CREATE OR REPLACE VIEW akas AS SELECT * FROM read_csv_auto('{url_akas}')")
duckdb.query(f"CREATE OR REPLACE VIEW crew AS SELECT * FROM read_csv_auto('{url_crew}')")
duckdb.query(f"CREATE OR REPLACE VIEW name AS SELECT * FROM read_csv_auto('{url_name}')")
duckdb.query(f"CREATE OR REPLACE VIEW rating AS SELECT * FROM read_csv_auto('{url_ratings}')")

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)

query_finale = """
    SELECT titles.tconst, titles.primaryTitle, akas.title, titles.startYear,titles.runtimeMinutes,tmdb.spoken_languages,titles.genres, name.primaryName,name.primaryProfession, name.knownForTitles, rating.averageRating,tmdb.popularity,tmdb.tagline, tmdb.overview,tmdb.poster_path, tmdb.video, tmdb.budget,tmdb.revenue
    FROM titles
    LEFT JOIN tmdb ON imdb_id = titles.tconst
    LEFT JOIN akas ON akas.titleId = titles.tconst
    LEFT JOIN crew ON crew.tconst = titles.tconst
    LEFT JOIN name ON name.nconst = crew.directors
    LEFT JOIN rating ON rating.tconst = titles.tconst
    WHERE titles.titleType = 'movie'
    AND titles.tconst NOT LIKE '%\\N%'
    AND titles.isAdult = 0
    AND titles.genres IS NOT NULL
    AND titles.genres NOT LIKE '%\\N%'
    AND titles.genres NOT LIKE '%Horror%'
    AND titles.genres NOT LIKE '%NaN%'
    AND titles.runtimeMinutes NOT LIKE '%\\N%'
    AND CAST(titles.runtimeMinutes AS INTEGER) >= 80
    AND CAST(titles.runtimeMinutes AS INTEGER) <= 220
    AND tmdb.spoken_languages LIKE '%fr%'
    AND titles.startYear NOT LIKE '%\\N%'
    AND CAST(titles.startYear as INTEGER) BETWEEN 1960 AND 2027
    AND tmdb.status != 'Canceled'
    AND rating.averageRating >= 5.0

    
"""
# on viens de rajouter le filtre rating, mais pas tester.
#akas.region = 'FR' AND

# %%
# EXÉCUTER LA REQUÊTE ET OBTENIR LE RÉSULTAT
df = duckdb.query(query_finale).to_df()
df.head(50)
# Out:
#        tconst       primaryTitle                                 title  \
# 0   tt0081176  My American Uncle                  Mon oncle d'Amérique
# 1   tt0081176  My American Uncle                 Min onkel fra Amerika
# 2   tt0081176  My American Uncle                     My American Uncle
# 3   tt0081176  My American Uncle                     My American Uncle
# 4   tt0081176  My American Uncle                    Amerika no oji-san
# 5   tt0081176  My American Uncle                   Amerikai nagybácsim
# 6   tt0081176  My American Uncle                       Amerikalı Amcam
# 7   tt0081176  My American Uncle                         Amerikan setä
# 8   tt0081176  My American Uncle           Dieu ne peut rien pour nous
# 9   tt0081176  My American Uncle                Mein Onkel aus Amerika
# 10  tt0081176  My American Uncle                    Meu Tio da América
# 11  tt0081176  My American Uncle                     Mi tío de América
# 12  tt0081176  My American Uncle              Min farbror från Amerika
# 13  tt0081176  My American Uncle                   Min onkel i Amerika
# 14  tt0081176  My American Uncle                     Mio zio d'America
# 15  tt0081176  My American Uncle                 Muj strýcek z Ameriky
# 16  tt0081176  My American Uncle                 My Uncle from America
# 17  tt0081176  My American Uncle                  O Meu Tio da América
# 18  tt0081176  My American Uncle              Ông Chú Người Mỹ Của Tôi
# 19  tt0081176  My American Uncle               Unchiul meu din America
# 20  tt0081176  My American Uncle                    Wujaszek z Ameryki
# 21  tt0081176  My American Uncle           Ο θείος μου από την Αμερική
# 22  tt0081176  My American Uncle                     Mi tío de América
# 23  tt0081176  My American Uncle             Мій американський дядечко
# 24  tt0081176  My American Uncle              Мой американский дядюшка
# 25  tt0081176  My American Uncle                    Чичо ми от Америка
# 26  tt0081176  My American Uncle                             アメリカの伯父さん
# 27  tt0081176  My American Uncle                                我的美国舅舅
# 28  tt0081176  My American Uncle                     Mi tío de América
# 29  tt0081176  My American Uncle                     Mi tío de América
# 30  tt0081176  My American Uncle                  Mon oncle d'Amérique
# 31  tt0081176  My American Uncle                  Mon oncle d'Amérique
# 32  tt0081176  My American Uncle                  Mon oncle d'Amérique
# 33  tt0081176  My American Uncle                 Min onkel fra Amerika
# 34  tt0081182        Death Watch                     La mort en direct
# 35  tt0081182        Death Watch                      Der gekaufte Tod
# 36  tt0081182        Death Watch                      Der gekaufte Tod
# 37  tt0081182        Death Watch                  La muerte en directo
# 38  tt0081182        Death Watch                  La muerte en directo
# 39  tt0081182        Death Watch                       A Morte ao Vivo
# 40  tt0081182        Death Watch                    A Morte em Directo
# 41  tt0081182        Death Watch                 De dood op het scherm
# 42  tt0081182        Death Watch                    Death in Full View
# 43  tt0081182        Death Watch        Death Watch - Der gekaufte Tod
# 44  tt0081182        Death Watch                        Direktsänd död
# 45  tt0081182        Death Watch                           Death Watch
# 46  tt0081182        Death Watch                 Halál egyenes adásban
# 47  tt0081182        Death Watch                 Kameran ljuger aldrig
# 48  tt0081182        Death Watch  Katherine Mortenhoen Ostettu Kuolema
# 49  tt0081182        Death Watch                     La mort en direct
#
#    startYear runtimeMinutes    spoken_languages                 genres  \
# 0       1980            125              ['fr']   Comedy,Drama,Romance
# 1       1980            125              ['fr']   Comedy,Drama,Romance
# 2       1980            125              ['fr']   Comedy,Drama,Romance
# 3       1980            125              ['fr']   Comedy,Drama,Romance
# 4       1980            125              ['fr']   Comedy,Drama,Romance
# 5       1980            125              ['fr']   Comedy,Drama,Romance
# 6       1980            125              ['fr']   Comedy,Drama,Romance
# 7       1980            125              ['fr']   Comedy,Drama,Romance
# 8       1980            125              ['fr']   Comedy,Drama,Romance
# 9       1980            125              ['fr']   Comedy,Drama,Romance
# 10      1980            125              ['fr']   Comedy,Drama,Romance
# 11      1980            125              ['fr']   Comedy,Drama,Romance
# 12      1980            125              ['fr']   Comedy,Drama,Romance
# 13      1980            125              ['fr']   Comedy,Drama,Romance
# 14      1980            125              ['fr']   Comedy,Drama,Romance
# 15      1980            125              ['fr']   Comedy,Drama,Romance
# 16      1980            125              ['fr']   Comedy,Drama,Romance
# 17      1980            125              ['fr']   Comedy,Drama,Romance
# 18      1980            125              ['fr']   Comedy,Drama,Romance
# 19      1980            125              ['fr']   Comedy,Drama,Romance
# 20      1980            125              ['fr']   Comedy,Drama,Romance
# 21      1980            125              ['fr']   Comedy,Drama,Romance
# 22      1980            125              ['fr']   Comedy,Drama,Romance
# 23      1980            125              ['fr']   Comedy,Drama,Romance
# 24      1980            125              ['fr']   Comedy,Drama,Romance
# 25      1980            125              ['fr']   Comedy,Drama,Romance
# 26      1980            125              ['fr']   Comedy,Drama,Romance
# 27      1980            125              ['fr']   Comedy,Drama,Romance
# 28      1980            125              ['fr']   Comedy,Drama,Romance
# 29      1980            125              ['fr']   Comedy,Drama,Romance
# 30      1980            125              ['fr']   Comedy,Drama,Romance
# 31      1980            125              ['fr']   Comedy,Drama,Romance
# 32      1980            125              ['fr']   Comedy,Drama,Romance
# 33      1980            125              ['fr']   Comedy,Drama,Romance
# 34      1980            117  ['en', 'fr', 'de']  Drama,Sci-Fi,Thriller
# 35      1980            117  ['en', 'fr', 'de']  Drama,Sci-Fi,Thriller
# 36      1980            117  ['en', 'fr', 'de']  Drama,Sci-Fi,Thriller
# 37      1980            117  ['en', 'fr', 'de']  Drama,Sci-Fi,Thriller
# 38      1980            117  ['en', 'fr', 'de']  Drama,Sci-Fi,Thriller
# 39      1980            117  ['en', 'fr', 'de']  Drama,Sci-Fi,Thriller
# 40      1980            117  ['en', 'fr', 'de']  Drama,Sci-Fi,Thriller
# 41      1980            117  ['en', 'fr', 'de']  Drama,Sci-Fi,Thriller
# 42      1980            117  ['en', 'fr', 'de']  Drama,Sci-Fi,Thriller
# 43      1980            117  ['en', 'fr', 'de']  Drama,Sci-Fi,Thriller
# 44      1980            117  ['en', 'fr', 'de']  Drama,Sci-Fi,Thriller
# 45      1980            117  ['en', 'fr', 'de']  Drama,Sci-Fi,Thriller
# 46      1980            117  ['en', 'fr', 'de']  Drama,Sci-Fi,Thriller
# 47      1980            117  ['en', 'fr', 'de']  Drama,Sci-Fi,Thriller
# 48      1980            117  ['en', 'fr', 'de']  Drama,Sci-Fi,Thriller
# 49      1980            117  ['en', 'fr', 'de']  Drama,Sci-Fi,Thriller
#
#            primaryName         primaryProfession  \
# 0        Alain Resnais    director,editor,writer
# 1        Alain Resnais    director,editor,writer
# 2        Alain Resnais    director,editor,writer
# 3        Alain Resnais    director,editor,writer
# 4        Alain Resnais    director,editor,writer
# 5        Alain Resnais    director,editor,writer
# 6        Alain Resnais    director,editor,writer
# 7        Alain Resnais    director,editor,writer
# 8        Alain Resnais    director,editor,writer
# 9        Alain Resnais    director,editor,writer
# 10       Alain Resnais    director,editor,writer
# 11       Alain Resnais    director,editor,writer
# 12       Alain Resnais    director,editor,writer
# 13       Alain Resnais    director,editor,writer
# 14       Alain Resnais    director,editor,writer
# 15       Alain Resnais    director,editor,writer
# 16       Alain Resnais    director,editor,writer
# 17       Alain Resnais    director,editor,writer
# 18       Alain Resnais    director,editor,writer
# 19       Alain Resnais    director,editor,writer
# 20       Alain Resnais    director,editor,writer
# 21       Alain Resnais    director,editor,writer
# 22       Alain Resnais    director,editor,writer
# 23       Alain Resnais    director,editor,writer
# 24       Alain Resnais    director,editor,writer
# 25       Alain Resnais    director,editor,writer
# 26       Alain Resnais    director,editor,writer
# 27       Alain Resnais    director,editor,writer
# 28       Alain Resnais    director,editor,writer
# 29       Alain Resnais    director,editor,writer
# 30       Alain Resnais    director,editor,writer
# 31       Alain Resnais    director,editor,writer
# 32       Alain Resnais    director,editor,writer
# 33       Alain Resnais    director,editor,writer
# 34  Bertrand Tavernier  director,writer,producer
# 35  Bertrand Tavernier  director,writer,producer
# 36  Bertrand Tavernier  director,writer,producer
# 37  Bertrand Tavernier  director,writer,producer
# 38  Bertrand Tavernier  director,writer,producer
# 39  Bertrand Tavernier  director,writer,producer
# 40  Bertrand Tavernier  director,writer,producer
# 41  Bertrand Tavernier  director,writer,producer
# 42  Bertrand Tavernier  director,writer,producer
# 43  Bertrand Tavernier  director,writer,producer
# 44  Bertrand Tavernier  director,writer,producer
# 45  Bertrand Tavernier  director,writer,producer
# 46  Bertrand Tavernier  director,writer,producer
# 47  Bertrand Tavernier  director,writer,producer
# 48  Bertrand Tavernier  director,writer,producer
# 49  Bertrand Tavernier  director,writer,producer
#
#                              knownForTitles  averageRating  popularity  \
# 0   tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 1   tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 2   tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 3   tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 4   tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 5   tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 6   tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 7   tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 8   tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 9   tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 10  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 11  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 12  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 13  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 14  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 15  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 16  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 17  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 18  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 19  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 20  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 21  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 22  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 23  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 24  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 25  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 26  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 27  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 28  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 29  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 30  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 31  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 32  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 33  tt0052893,tt0054632,tt0119828,tt0081176            7.6       7.760
# 34  tt0088318,tt0071622,tt0115822,tt0186730            6.5       8.173
# 35  tt0088318,tt0071622,tt0115822,tt0186730            6.5       8.173
# 36  tt0088318,tt0071622,tt0115822,tt0186730            6.5       8.173
# 37  tt0088318,tt0071622,tt0115822,tt0186730            6.5       8.173
# 38  tt0088318,tt0071622,tt0115822,tt0186730            6.5       8.173
# 39  tt0088318,tt0071622,tt0115822,tt0186730            6.5       8.173
# 40  tt0088318,tt0071622,tt0115822,tt0186730            6.5       8.173
# 41  tt0088318,tt0071622,tt0115822,tt0186730            6.5       8.173
# 42  tt0088318,tt0071622,tt0115822,tt0186730            6.5       8.173
# 43  tt0088318,tt0071622,tt0115822,tt0186730            6.5       8.173
# 44  tt0088318,tt0071622,tt0115822,tt0186730            6.5       8.173
# 45  tt0088318,tt0071622,tt0115822,tt0186730            6.5       8.173
# 46  tt0088318,tt0071622,tt0115822,tt0186730            6.5       8.173
# 47  tt0088318,tt0071622,tt0115822,tt0186730            6.5       8.173
# 48  tt0088318,tt0071622,tt0115822,tt0186730            6.5       8.173
# 49  tt0088318,tt0071622,tt0115822,tt0186730            6.5       8.173
#
#                                               tagline  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34  She's the target of every eye… including eyes ...
# 35  She's the target of every eye… including eyes ...
# 36  She's the target of every eye… including eyes ...
# 37  She's the target of every eye… including eyes ...
# 38  She's the target of every eye… including eyes ...
# 39  She's the target of every eye… including eyes ...
# 40  She's the target of every eye… including eyes ...
# 41  She's the target of every eye… including eyes ...
# 42  She's the target of every eye… including eyes ...
# 43  She's the target of every eye… including eyes ...
# 44  She's the target of every eye… including eyes ...
# 45  She's the target of every eye… including eyes ...
# 46  She's the target of every eye… including eyes ...
# 47  She's the target of every eye… including eyes ...
# 48  She's the target of every eye… including eyes ...
# 49  She's the target of every eye… including eyes ...
#
#                                              overview  \
# 0   Prof. Henri Laborit uses the stories of the li...
# 1   Prof. Henri Laborit uses the stories of the li...
# 2   Prof. Henri Laborit uses the stories of the li...
# 3   Prof. Henri Laborit uses the stories of the li...
# 4   Prof. Henri Laborit uses the stories of the li...
# 5   Prof. Henri Laborit uses the stories of the li...
# 6   Prof. Henri Laborit uses the stories of the li...
# 7   Prof. Henri Laborit uses the stories of the li...
# 8   Prof. Henri Laborit uses the stories of the li...
# 9   Prof. Henri Laborit uses the stories of the li...
# 10  Prof. Henri Laborit uses the stories of the li...
# 11  Prof. Henri Laborit uses the stories of the li...
# 12  Prof. Henri Laborit uses the stories of the li...
# 13  Prof. Henri Laborit uses the stories of the li...
# 14  Prof. Henri Laborit uses the stories of the li...
# 15  Prof. Henri Laborit uses the stories of the li...
# 16  Prof. Henri Laborit uses the stories of the li...
# 17  Prof. Henri Laborit uses the stories of the li...
# 18  Prof. Henri Laborit uses the stories of the li...
# 19  Prof. Henri Laborit uses the stories of the li...
# 20  Prof. Henri Laborit uses the stories of the li...
# 21  Prof. Henri Laborit uses the stories of the li...
# 22  Prof. Henri Laborit uses the stories of the li...
# 23  Prof. Henri Laborit uses the stories of the li...
# 24  Prof. Henri Laborit uses the stories of the li...
# 25  Prof. Henri Laborit uses the stories of the li...
# 26  Prof. Henri Laborit uses the stories of the li...
# 27  Prof. Henri Laborit uses the stories of the li...
# 28  Prof. Henri Laborit uses the stories of the li...
# 29  Prof. Henri Laborit uses the stories of the li...
# 30  Prof. Henri Laborit uses the stories of the li...
# 31  Prof. Henri Laborit uses the stories of the li...
# 32  Prof. Henri Laborit uses the stories of the li...
# 33  Prof. Henri Laborit uses the stories of the li...
# 34  In a future world where the disease has been f...
# 35  In a future world where the disease has been f...
# 36  In a future world where the disease has been f...
# 37  In a future world where the disease has been f...
# 38  In a future world where the disease has been f...
# 39  In a future world where the disease has been f...
# 40  In a future world where the disease has been f...
# 41  In a future world where the disease has been f...
# 42  In a future world where the disease has been f...
# 43  In a future world where the disease has been f...
# 44  In a future world where the disease has been f...
# 45  In a future world where the disease has been f...
# 46  In a future world where the disease has been f...
# 47  In a future world where the disease has been f...
# 48  In a future world where the disease has been f...
# 49  In a future world where the disease has been f...
#
#                          poster_path  video  budget  revenue
# 0   /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 1   /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 2   /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 3   /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 4   /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 5   /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 6   /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 7   /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 8   /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 9   /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 10  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 11  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 12  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 13  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 14  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 15  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 16  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 17  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 18  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 19  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 20  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 21  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 22  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 23  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 24  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 25  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 26  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 27  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 28  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 29  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 30  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 31  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 32  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 33  /1IV44owj1uZnD0bStusyY4PexP2.jpg  False       0        0
# 34  /wSuvftmbs0fInDe69u8yDUtElsp.jpg  False       0        0
# 35  /wSuvftmbs0fInDe69u8yDUtElsp.jpg  False       0        0
# 36  /wSuvftmbs0fInDe69u8yDUtElsp.jpg  False       0        0
# 37  /wSuvftmbs0fInDe69u8yDUtElsp.jpg  False       0        0
# 38  /wSuvftmbs0fInDe69u8yDUtElsp.jpg  False       0        0
# 39  /wSuvftmbs0fInDe69u8yDUtElsp.jpg  False       0        0
# 40  /wSuvftmbs0fInDe69u8yDUtElsp.jpg  False       0        0
# 41  /wSuvftmbs0fInDe69u8yDUtElsp.jpg  False       0        0
# 42  /wSuvftmbs0fInDe69u8yDUtElsp.jpg  False       0        0
# 43  /wSuvftmbs0fInDe69u8yDUtElsp.jpg  False       0        0
# 44  /wSuvftmbs0fInDe69u8yDUtElsp.jpg  False       0        0
# 45  /wSuvftmbs0fInDe69u8yDUtElsp.jpg  False       0        0
# 46  /wSuvftmbs0fInDe69u8yDUtElsp.jpg  False       0        0
# 47  /wSuvftmbs0fInDe69u8yDUtElsp.jpg  False       0        0
# 48  /wSuvftmbs0fInDe69u8yDUtElsp.jpg  False       0        0
# 49  /wSuvftmbs0fInDe69u8yDUtElsp.jpg  False       0        0

# %%
df.describe()
# Out:
#        averageRating    popularity        budget       revenue
# count   10585.000000  10719.000000  1.071900e+04  1.071900e+04
# mean        6.106982      5.159943  2.931698e+06  7.309966e+06
# std         0.969484     18.240558  1.523542e+07  5.492054e+07
# min         1.200000      0.600000  0.000000e+00  0.000000e+00
# 25%         5.500000      1.164000  0.000000e+00  0.000000e+00
# 50%         6.200000      2.299000  0.000000e+00  0.000000e+00
# 75%         6.800000      5.953500  0.000000e+00  0.000000e+00
# max         9.400000   1170.178000  2.700000e+08  2.264162e+09

# %%
df.shape
# Out:
# (175826, 18)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 175826 entries, 0 to 175825
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   tconst             175826 non-null  str
#  1   primaryTitle       175826 non-null  str
#  2   title              175826 non-null  str
#  3   startYear          175826 non-null  str
#  4   runtimeMinutes     175826 non-null  str
#  5   spoken_languages   175826 non-null  str
#  6   genres             175826 non-null  str
#  7   primaryName        162752 non-null  str
#  8   primaryProfession  162752 non-null  str
#  9   knownForTitles     162752 non-null  str
#  10  averageRating      175328 non-null  float64
#  11  popularity         175826 non-null  float64
#  12  tagline            62285 non-null   str
#  13  overview           173035 non-null  str
#  14  poster_path        172847 non-null  str
#  15  video              175826 non-null  bool
#  16  budget             175826 non-null  int64
#  17  revenue            175826 non-null  int64
# dtypes: bool(1), float64(2), int64(2), str(13)
# memory usage: 23.0 MB
